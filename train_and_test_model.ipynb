# %% [markdown]
# # How to train and test DQN model class

# %%
#!pip install gymnasium[atari]
#!pip install gymnasium[accept-rom-license]
#!pip install "gym[accept-rom-license, atari]"
#!pip install PyVirtualDisplay

# %%
# import module we'll need to import our custom module
from shutil import copytree

on_kaggle_server = False

if on_kaggle_server:
    kaggle_input = "/kaggle/input/dqnmodel/DQN"
    kaggle_output = "/kaggle/working/DQN"
    copytree(kaggle_input,kaggle_output)

# %%
from DQN.DQN_model import DQNmodel
# Out:
# 2024-01-28 16:30:05.601735: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-28 16:30:05.601777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-28 16:30:05.602975: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-28 16:30:05.610005: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-28 16:30:06.527598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model_type = "vanilla"
model_detail = "normal"

model_path = f"./results/{model_type}/{model_detail}/model"
checkpoint_dir = f"./results/{model_type}/{model_detail}/checkpoints"

model = DQNmodel(
                    load_model_from=model_path,
                    save_model_to=model_path,
                    checkpoint_dir=checkpoint_dir,
                    env_path="ALE/MsPacman-v5",
                    dqn_type= model_type
                )
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-01-28 16:30:17.280467: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Restored from ./results/vanilla/normal/checkpoints/ckpt-11
# Model loaded

# %%
#model.train(total_timesteps=1000000)

# %%
logs = model.evaluate(total_episodes=1000)
# Out:
# Evaluation: 100%|██████████| 1000/1000 [16:06<00:00,  1.03episode/s]
# =========================== Evaluation Summary ===========================
# Episode Length Mean: 764
# Episode Reward Mean: 80
# Episode Score Mean: 1305
# Exploration Rate: 0.05
# Episodes: 1000
# Time Elapsed: 983.13 seconds
# Total Timesteps: 185625
# CPU Memory Usage: 1.03 GB
# CPU Usage: 34.7%
# ==========================================================================
# Evaluation finished

# %%
logs.save_data()
