# %% [markdown]
# # How to train and test DQN model class

# %%
#!pip install gymnasium[atari]
#!pip install gymnasium[accept-rom-license]
#!pip install "gym[accept-rom-license, atari]"
#!pip install PyVirtualDisplay

# %%
# import module we'll need to import our custom module
from shutil import copytree

on_kaggle_server = False

if on_kaggle_server:
    kaggle_input = "/kaggle/input/dqnmodel/DQN"
    kaggle_output = "/kaggle/working/DQN"
    copytree(kaggle_input,kaggle_output)

# %%
from DQN.DQN_model import DQNmodel
# Out:
# 2024-01-26 16:13:59.735449: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 16:13:59.735805: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 16:13:59.816785: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 16:13:59.990755: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-26 16:14:01.643968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model_type = "vanilla"
model_details = "_test"

model_path = f"./{model_type}_DQN/model{model_details}"
checkpoint_dir = f"./{model_type}_DQN/checkpoints{model_details}"

model = DQNmodel(
                    save_model_to=model_path,
                    checkpoint_dir=checkpoint_dir,
                    env_path="ALE/MsPacman-v5",
                    dqn_type= model_type
                )
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# 2024-01-26 16:14:16.724633: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Restored from ./vanilla_DQN/checkpoints_test/ckpt-1

# %%
model.train(total_timesteps=1000000)
# Out:
# GPU is not available, using CPU instead
#
# Resuming training from step 100231
# Initial warm up: 10000 steps
# Warm up: 100%|██████████| 10000/10000 [00:29<00:00, 335.05step/s]
# Training: 100%|██████████| 50/50 [06:40<00:00,  8.00s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 679
# Episode Reward Mean: 60
# Episode Score Mean: 865
# Exploration Rate: 0.05
# Episodes: 701
# Time per episode: 422
# Frame per second: 56
# Time Elapsed: 620.09 seconds
# Total Timesteps: 108345
# CPU Memory Usage: 2.24 GB
# CPU Usage: 30.0%
# Learning Rate: 0.00025
# Loss: 0.81
# Num Updates: 0
# ==========================================================================
# Training: 100%|██████████| 50/50 [06:41<00:00,  8.03s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 673
# Episode Reward Mean: 60
# Episode Score Mean: 982
# Exploration Rate: 0.05
# Episodes: 751
# Time per episode: 831
# Frame per second: 81
# Time Elapsed: 1021.52 seconds
# Total Timesteps: 116466
# CPU Memory Usage: 2.58 GB
# CPU Usage: 32.3%
# Learning Rate: 0.00025
# Loss: 0.82
# Num Updates: 1
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:05<00:00,  8.51s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 707
# Episode Reward Mean: 66
# Episode Score Mean: 1028
# Exploration Rate: 0.05
# Episodes: 801
# Time per episode: 1240
# Frame per second: 81
# Time Elapsed: 1446.78 seconds
# Total Timesteps: 125035
# CPU Memory Usage: 2.9 GB
# CPU Usage: 34.3%
# Learning Rate: 0.00025
# Loss: 0.88
# Num Updates: 2
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:20<00:00,  8.81s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 730
# Episode Reward Mean: 71
# Episode Score Mean: 1114
# Exploration Rate: 0.05
# Episodes: 851
# Time per episode: 1673
# Frame per second: 80
# Time Elapsed: 1887.19 seconds
# Total Timesteps: 133890
# CPU Memory Usage: 3.24 GB
# CPU Usage: 36.5%
# Learning Rate: 0.00025
# Loss: 0.97
# Num Updates: 3
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:40<00:00,  9.22s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 759
# Episode Reward Mean: 71
# Episode Score Mean: 1144
# Exploration Rate: 0.05
# Episodes: 901
# Time per episode: 2132
# Frame per second: 80
# Time Elapsed: 2348.07 seconds
# Total Timesteps: 143129
# CPU Memory Usage: 3.62 GB
# CPU Usage: 39.0%
# Learning Rate: 0.00025
# Loss: 0.9
# Num Updates: 4
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:17<00:00,  8.76s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 721
# Episode Reward Mean: 72
# Episode Score Mean: 1137
# Exploration Rate: 0.05
# Episodes: 951
# Time per episode: 2580
# Frame per second: 80
# Time Elapsed: 2785.84 seconds
# Total Timesteps: 151893
# CPU Memory Usage: 3.94 GB
# CPU Usage: 41.1%
# Learning Rate: 0.00025
# Loss: 0.91
# Num Updates: 5
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:44<00:00,  9.29s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 763
# Episode Reward Mean: 75
# Episode Score Mean: 1286
# Exploration Rate: 0.05
# Episodes: 1001
# Time per episode: 3023
# Frame per second: 80
# Time Elapsed: 3250.14 seconds
# Total Timesteps: 161172
# CPU Memory Usage: 4.28 GB
# CPU Usage: 43.3%
# Learning Rate: 0.00025
# Loss: 1.06
# Num Updates: 6
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:34<00:00,  9.09s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 748
# Episode Reward Mean: 76
# Episode Score Mean: 1285
# Exploration Rate: 0.05
# Episodes: 1051
# Time per episode: 3482
# Frame per second: 80
# Time Elapsed: 3704.63 seconds
# Total Timesteps: 170229
# CPU Memory Usage: 4.64 GB
# CPU Usage: 45.7%
# Learning Rate: 0.00025
# Loss: 1.1
# Num Updates: 7
# ==========================================================================
# Training: 100%|██████████| 50/50 [06:59<00:00,  8.39s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 687
# Episode Reward Mean: 69
# Episode Score Mean: 1088
# Exploration Rate: 0.05
# Episodes: 1101
# Time per episode: 3929
# Frame per second: 79
# Time Elapsed: 4124.23 seconds
# Total Timesteps: 178569
# CPU Memory Usage: 4.93 GB
# CPU Usage: 48.0%
# Learning Rate: 0.00025
# Loss: 1.01
# Num Updates: 7
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:05<00:00,  9.71s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 793
# Episode Reward Mean: 80
# Episode Score Mean: 1345
# Exploration Rate: 0.05
# Episodes: 1151
# Time per episode: 4371
# Frame per second: 79
# Time Elapsed: 4609.61 seconds
# Total Timesteps: 188188
# CPU Memory Usage: 5.04 GB
# CPU Usage: 48.3%
# Learning Rate: 0.00025
# Loss: 1.01
# Num Updates: 8
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:18<00:00,  9.97s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 807
# Episode Reward Mean: 84
# Episode Score Mean: 1409
# Exploration Rate: 0.05
# Episodes: 1201
# Time per episode: 4871
# Frame per second: 79
# Time Elapsed: 5108.14 seconds
# Total Timesteps: 198021
# CPU Memory Usage: 5.08 GB
# CPU Usage: 52.3%
# Learning Rate: 0.00025
# Loss: 0.92
# Num Updates: 9
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:39<00:00,  9.19s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 752
# Episode Reward Mean: 79
# Episode Score Mean: 1358
# Exploration Rate: 0.05
# Episodes: 1251
# Time per episode: 5350
# Frame per second: 79
# Time Elapsed: 5567.8 seconds
# Total Timesteps: 207148
# CPU Memory Usage: 5.13 GB
# CPU Usage: 52.4%
# Learning Rate: 0.00025
# Loss: 1.0
# Num Updates: 10
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:02<00:00,  8.45s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 694
# Episode Reward Mean: 73
# Episode Score Mean: 1276
# Exploration Rate: 0.05
# Episodes: 1301
# Time per episode: 5792
# Frame per second: 79
# Time Elapsed: 5990.51 seconds
# Total Timesteps: 215535
# CPU Memory Usage: 5.17 GB
# CPU Usage: 52.7%
# Learning Rate: 0.00025
# Loss: 0.97
# Num Updates: 11
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:50<00:00,  9.41s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 768
# Episode Reward Mean: 82
# Episode Score Mean: 1446
# Exploration Rate: 0.05
# Episodes: 1351
# Time per episode: 6234
# Frame per second: 79
# Time Elapsed: 6461.06 seconds
# Total Timesteps: 224869
# CPU Memory Usage: 5.19 GB
# CPU Usage: 52.8%
# Learning Rate: 0.00025
# Loss: 1.11
# Num Updates: 12
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:20<00:00,  8.82s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 724
# Episode Reward Mean: 78
# Episode Score Mean: 1288
# Exploration Rate: 0.05
# Episodes: 1401
# Time per episode: 6694
# Frame per second: 80
# Time Elapsed: 6902.05 seconds
# Total Timesteps: 233646
# CPU Memory Usage: 5.23 GB
# CPU Usage: 53.1%
# Learning Rate: 0.00025
# Loss: 1.04
# Num Updates: 13
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:48<00:00,  9.37s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 770
# Episode Reward Mean: 83
# Episode Score Mean: 1534
# Exploration Rate: 0.05
# Episodes: 1451
# Time per episode: 7144
# Frame per second: 80
# Time Elapsed: 7370.71 seconds
# Total Timesteps: 242999
# CPU Memory Usage: 5.25 GB
# CPU Usage: 53.2%
# Learning Rate: 0.00025
# Loss: 1.02
# Num Updates: 14
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:35<00:00,  9.10s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 740
# Episode Reward Mean: 81
# Episode Score Mean: 1329
# Exploration Rate: 0.05
# Episodes: 1501
# Time per episode: 7605
# Frame per second: 79
# Time Elapsed: 7825.79 seconds
# Total Timesteps: 251971
# CPU Memory Usage: 5.29 GB
# CPU Usage: 54.0%
# Learning Rate: 0.00025
# Loss: 1.06
# Num Updates: 15
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:42<00:00,  9.26s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 743
# Episode Reward Mean: 81
# Episode Score Mean: 1558
# Exploration Rate: 0.05
# Episodes: 1551
# Time per episode: 8068
# Frame per second: 78
# Time Elapsed: 8288.55 seconds
# Total Timesteps: 260993
# CPU Memory Usage: 5.32 GB
# CPU Usage: 54.2%
# Learning Rate: 0.00025
# Loss: 1.23
# Num Updates: 16
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:39<00:00,  9.20s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 764
# Episode Reward Mean: 86
# Episode Score Mean: 1495
# Exploration Rate: 0.05
# Episodes: 1601
# Time per episode: 8522
# Frame per second: 81
# Time Elapsed: 8748.39 seconds
# Total Timesteps: 270252
# CPU Memory Usage: 5.36 GB
# CPU Usage: 54.5%
# Learning Rate: 0.00025
# Loss: 1.28
# Num Updates: 17
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:14<00:00,  9.89s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 792
# Episode Reward Mean: 87
# Episode Score Mean: 1468
# Exploration Rate: 0.05
# Episodes: 1651
# Time per episode: 8994
# Frame per second: 78
# Time Elapsed: 9242.77 seconds
# Total Timesteps: 279913
# CPU Memory Usage: 5.4 GB
# CPU Usage: 57.9%
# Learning Rate: 0.00025
# Loss: 1.12
# Num Updates: 17
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:36<00:00, 10.34s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 829
# Episode Reward Mean: 90
# Episode Score Mean: 1497
# Exploration Rate: 0.05
# Episodes: 1701
# Time per episode: 9516
# Frame per second: 78
# Time Elapsed: 9759.58 seconds
# Total Timesteps: 289996
# CPU Memory Usage: 5.44 GB
# CPU Usage: 58.6%
# Learning Rate: 0.00025
# Loss: 1.25
# Num Updates: 18
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:20<00:00, 10.00s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 783
# Episode Reward Mean: 86
# Episode Score Mean: 1490
# Exploration Rate: 0.05
# Episodes: 1751
# Time per episode: 10014
# Frame per second: 76
# Time Elapsed: 10259.6 seconds
# Total Timesteps: 299536
# CPU Memory Usage: 5.46 GB
# CPU Usage: 58.5%
# Learning Rate: 0.00025
# Loss: 1.13
# Num Updates: 19
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:11<00:00,  9.82s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 781
# Episode Reward Mean: 86
# Episode Score Mean: 1558
# Exploration Rate: 0.05
# Episodes: 1801
# Time per episode: 10520
# Frame per second: 77
# Time Elapsed: 10750.7 seconds
# Total Timesteps: 309035
# CPU Memory Usage: 5.5 GB
# CPU Usage: 59.2%
# Learning Rate: 0.00025
# Loss: 1.18
# Num Updates: 20
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:27<00:00, 10.15s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 812
# Episode Reward Mean: 91
# Episode Score Mean: 1580
# Exploration Rate: 0.05
# Episodes: 1851
# Time per episode: 11021
# Frame per second: 78
# Time Elapsed: 11258.34 seconds
# Total Timesteps: 318942
# CPU Memory Usage: 5.55 GB
# CPU Usage: 59.7%
# Learning Rate: 0.00025
# Loss: 1.05
# Num Updates: 21
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:54<00:00,  9.48s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 759
# Episode Reward Mean: 85
# Episode Score Mean: 1416
# Exploration Rate: 0.05
# Episodes: 1901
# Time per episode: 11505
# Frame per second: 78
# Time Elapsed: 11732.57 seconds
# Total Timesteps: 328134
# CPU Memory Usage: 5.56 GB
# CPU Usage: 59.9%
# Learning Rate: 0.00025
# Loss: 1.13
# Num Updates: 22
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:23<00:00, 10.07s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 800
# Episode Reward Mean: 88
# Episode Score Mean: 1564
# Exploration Rate: 0.05
# Episodes: 1951
# Time per episode: 12002
# Frame per second: 77
# Time Elapsed: 12236.27 seconds
# Total Timesteps: 337869
# CPU Memory Usage: 5.6 GB
# CPU Usage: 60.3%
# Learning Rate: 0.00025
# Loss: 1.09
# Num Updates: 23
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:04<00:00,  9.70s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 794
# Episode Reward Mean: 88
# Episode Score Mean: 1523
# Exploration Rate: 0.05
# Episodes: 2001
# Time per episode: 12493
# Frame per second: 80
# Time Elapsed: 12721.13 seconds
# Total Timesteps: 347506
# CPU Memory Usage: 5.66 GB
# CPU Usage: 59.9%
# Learning Rate: 0.00025
# Loss: 1.19
# Num Updates: 24
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:11<00:00,  9.83s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 803
# Episode Reward Mean: 89
# Episode Score Mean: 1633
# Exploration Rate: 0.05
# Episodes: 2051
# Time per episode: 12982
# Frame per second: 80
# Time Elapsed: 13212.85 seconds
# Total Timesteps: 357284
# CPU Memory Usage: 5.67 GB
# CPU Usage: 59.8%
# Learning Rate: 0.00025
# Loss: 1.15
# Num Updates: 25
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:26<00:00, 10.13s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 829
# Episode Reward Mean: 91
# Episode Score Mean: 1679
# Exploration Rate: 0.05
# Episodes: 2101
# Time per episode: 13478
# Frame per second: 80
# Time Elapsed: 13719.47 seconds
# Total Timesteps: 367362
# CPU Memory Usage: 5.73 GB
# CPU Usage: 60.5%
# Learning Rate: 0.00025
# Loss: 1.26
# Num Updates: 26
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:32<00:00, 10.25s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 837
# Episode Reward Mean: 92
# Episode Score Mean: 1735
# Exploration Rate: 0.05
# Episodes: 2151
# Time per episode: 13987
# Frame per second: 79
# Time Elapsed: 14232.18 seconds
# Total Timesteps: 377543
# CPU Memory Usage: 5.74 GB
# CPU Usage: 60.5%
# Learning Rate: 0.00025
# Loss: 1.17
# Num Updates: 27
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:51<00:00,  9.43s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 771
# Episode Reward Mean: 86
# Episode Score Mean: 1533
# Exploration Rate: 0.05
# Episodes: 2201
# Time per episode: 14477
# Frame per second: 79
# Time Elapsed: 14703.8 seconds
# Total Timesteps: 386900
# CPU Memory Usage: 5.78 GB
# CPU Usage: 60.6%
# Learning Rate: 0.00025
# Loss: 1.14
# Num Updates: 28
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:53<00:00,  9.47s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 776
# Episode Reward Mean: 86
# Episode Score Mean: 1487
# Exploration Rate: 0.05
# Episodes: 2251
# Time per episode: 14951
# Frame per second: 80
# Time Elapsed: 15177.53 seconds
# Total Timesteps: 396327
# CPU Memory Usage: 5.82 GB
# CPU Usage: 61.1%
# Learning Rate: 0.00025
# Loss: 1.09
# Num Updates: 29
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:08<00:00,  9.77s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 797
# Episode Reward Mean: 89
# Episode Score Mean: 1660
# Exploration Rate: 0.05
# Episodes: 2301
# Time per episode: 15437
# Frame per second: 79
# Time Elapsed: 15666.16 seconds
# Total Timesteps: 406021
# CPU Memory Usage: 5.85 GB
# CPU Usage: 61.3%
# Learning Rate: 0.00025
# Loss: 1.29
# Num Updates: 30
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:59<00:00,  9.59s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 782
# Episode Reward Mean: 88
# Episode Score Mean: 1609
# Exploration Rate: 0.05
# Episodes: 2351
# Time per episode: 15916
# Frame per second: 79
# Time Elapsed: 16145.54 seconds
# Total Timesteps: 415541
# CPU Memory Usage: 5.89 GB
# CPU Usage: 61.7%
# Learning Rate: 0.00025
# Loss: 1.33
# Num Updates: 31
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:32<00:00, 10.26s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 837
# Episode Reward Mean: 92
# Episode Score Mean: 1578
# Exploration Rate: 0.05
# Episodes: 2401
# Time per episode: 16413
# Frame per second: 79
# Time Elapsed: 16658.53 seconds
# Total Timesteps: 425733
# CPU Memory Usage: 5.94 GB
# CPU Usage: 61.7%
# Learning Rate: 0.00025
# Loss: 1.23
# Num Updates: 32
# ==========================================================================
# Training: 100%|██████████| 50/50 [07:57<00:00,  9.55s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 779
# Episode Reward Mean: 90
# Episode Score Mean: 1784
# Exploration Rate: 0.05
# Episodes: 2451
# Time per episode: 16906
# Frame per second: 79
# Time Elapsed: 17135.95 seconds
# Total Timesteps: 435210
# CPU Memory Usage: 5.96 GB
# CPU Usage: 62.1%
# Learning Rate: 0.00025
# Loss: 1.25
# Num Updates: 33
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:15<00:00,  9.91s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 806
# Episode Reward Mean: 91
# Episode Score Mean: 1681
# Exploration Rate: 0.05
# Episodes: 2501
# Time per episode: 17397
# Frame per second: 79
# Time Elapsed: 17631.51 seconds
# Total Timesteps: 445043
# CPU Memory Usage: 6.0 GB
# CPU Usage: 62.2%
# Learning Rate: 0.00025
# Loss: 1.21
# Num Updates: 34
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:07<00:00,  9.75s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 796
# Episode Reward Mean: 89
# Episode Score Mean: 1423
# Exploration Rate: 0.05
# Episodes: 2551
# Time per episode: 17884
# Frame per second: 79
# Time Elapsed: 18119.25 seconds
# Total Timesteps: 454719
# CPU Memory Usage: 6.04 GB
# CPU Usage: 62.6%
# Learning Rate: 0.00025
# Loss: 1.35
# Num Updates: 35
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:13<00:00,  9.86s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 803
# Episode Reward Mean: 92
# Episode Score Mean: 1737
# Exploration Rate: 0.05
# Episodes: 2601
# Time per episode: 18379
# Frame per second: 79
# Time Elapsed: 18612.26 seconds
# Total Timesteps: 464499
# CPU Memory Usage: 6.07 GB
# CPU Usage: 62.8%
# Learning Rate: 0.00025
# Loss: 1.32
# Num Updates: 36
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:05<00:00,  9.72s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 792
# Episode Reward Mean: 87
# Episode Score Mean: 1441
# Exploration Rate: 0.05
# Episodes: 2651
# Time per episode: 18867
# Frame per second: 79
# Time Elapsed: 19098.09 seconds
# Total Timesteps: 474136
# CPU Memory Usage: 6.11 GB
# CPU Usage: 63.0%
# Learning Rate: 0.00025
# Loss: 1.27
# Num Updates: 37
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:20<00:00, 10.00s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 814
# Episode Reward Mean: 89
# Episode Score Mean: 1629
# Exploration Rate: 0.05
# Episodes: 2701
# Time per episode: 19356
# Frame per second: 79
# Time Elapsed: 19598.13 seconds
# Total Timesteps: 484056
# CPU Memory Usage: 6.15 GB
# CPU Usage: 63.2%
# Learning Rate: 0.00025
# Loss: 1.37
# Num Updates: 38
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:41<00:00, 10.42s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 847
# Episode Reward Mean: 93
# Episode Score Mean: 1648
# Exploration Rate: 0.05
# Episodes: 2751
# Time per episode: 19871
# Frame per second: 79
# Time Elapsed: 20119.21 seconds
# Total Timesteps: 494384
# CPU Memory Usage: 6.19 GB
# CPU Usage: 63.5%
# Learning Rate: 0.00025
# Loss: 1.28
# Num Updates: 39
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:29<00:00, 10.19s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 830
# Episode Reward Mean: 93
# Episode Score Mean: 1694
# Exploration Rate: 0.05
# Episodes: 2801
# Time per episode: 20381
# Frame per second: 79
# Time Elapsed: 20628.7 seconds
# Total Timesteps: 504481
# CPU Memory Usage: 6.22 GB
# CPU Usage: 64.0%
# Learning Rate: 0.00025
# Loss: 1.32
# Num Updates: 40
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:31<00:00, 10.23s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 832
# Episode Reward Mean: 93
# Episode Score Mean: 1632
# Exploration Rate: 0.05
# Episodes: 2851
# Time per episode: 20894
# Frame per second: 79
# Time Elapsed: 21140.31 seconds
# Total Timesteps: 514638
# CPU Memory Usage: 6.26 GB
# CPU Usage: 64.1%
# Learning Rate: 0.00025
# Loss: 1.31
# Num Updates: 41
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:54<00:00, 10.69s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 869
# Episode Reward Mean: 94
# Episode Score Mean: 1587
# Exploration Rate: 0.05
# Episodes: 2901
# Time per episode: 21408
# Frame per second: 79
# Time Elapsed: 21674.68 seconds
# Total Timesteps: 525239
# CPU Memory Usage: 6.3 GB
# CPU Usage: 64.3%
# Learning Rate: 0.00025
# Loss: 1.19
# Num Updates: 42
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:15<00:00,  9.90s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 806
# Episode Reward Mean: 89
# Episode Score Mean: 1602
# Exploration Rate: 0.05
# Episodes: 2951
# Time per episode: 21935
# Frame per second: 79
# Time Elapsed: 22169.89 seconds
# Total Timesteps: 535055
# CPU Memory Usage: 6.34 GB
# CPU Usage: 64.7%
# Learning Rate: 0.00025
# Loss: 1.42
# Num Updates: 43
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:44<00:00, 10.48s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 851
# Episode Reward Mean: 92
# Episode Score Mean: 1711
# Exploration Rate: 0.05
# Episodes: 3001
# Time per episode: 22444
# Frame per second: 79
# Time Elapsed: 22694.03 seconds
# Total Timesteps: 545447
# CPU Memory Usage: 6.37 GB
# CPU Usage: 64.8%
# Learning Rate: 0.00025
# Loss: 1.22
# Num Updates: 44
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:09<00:00,  9.78s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 793
# Episode Reward Mean: 87
# Episode Score Mean: 1512
# Exploration Rate: 0.05
# Episodes: 3051
# Time per episode: 22958
# Frame per second: 79
# Time Elapsed: 23183.22 seconds
# Total Timesteps: 555077
# CPU Memory Usage: 6.41 GB
# CPU Usage: 65.7%
# Learning Rate: 0.00025
# Loss: 1.38
# Num Updates: 45
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:31<00:00, 10.24s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 840
# Episode Reward Mean: 94
# Episode Score Mean: 1673
# Exploration Rate: 0.05
# Episodes: 3101
# Time per episode: 23458
# Frame per second: 80
# Time Elapsed: 23695.19 seconds
# Total Timesteps: 565285
# CPU Memory Usage: 6.45 GB
# CPU Usage: 66.3%
# Learning Rate: 0.00025
# Loss: 1.4
# Num Updates: 46
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:14<00:00,  9.88s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 774
# Episode Reward Mean: 85
# Episode Score Mean: 1466
# Exploration Rate: 0.05
# Episodes: 3151
# Time per episode: 23958
# Frame per second: 76
# Time Elapsed: 24189.2 seconds
# Total Timesteps: 574688
# CPU Memory Usage: 6.49 GB
# CPU Usage: 67.0%
# Learning Rate: 0.00025
# Loss: 1.19
# Num Updates: 47
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:16<00:00,  9.93s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 807
# Episode Reward Mean: 87
# Episode Score Mean: 1618
# Exploration Rate: 0.05
# Episodes: 3201
# Time per episode: 24444
# Frame per second: 79
# Time Elapsed: 24685.94 seconds
# Total Timesteps: 584504
# CPU Memory Usage: 6.52 GB
# CPU Usage: 66.5%
# Learning Rate: 0.00025
# Loss: 1.33
# Num Updates: 48
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:09<00:00,  9.79s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 782
# Episode Reward Mean: 85
# Episode Score Mean: 1527
# Exploration Rate: 0.05
# Episodes: 3251
# Time per episode: 24949
# Frame per second: 78
# Time Elapsed: 25175.4 seconds
# Total Timesteps: 594021
# CPU Memory Usage: 6.56 GB
# CPU Usage: 67.1%
# Learning Rate: 0.00025
# Loss: 1.34
# Num Updates: 49
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:34<00:00, 10.30s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 844
# Episode Reward Mean: 93
# Episode Score Mean: 1810
# Exploration Rate: 0.05
# Episodes: 3301
# Time per episode: 25441
# Frame per second: 80
# Time Elapsed: 25690.33 seconds
# Total Timesteps: 604283
# CPU Memory Usage: 6.6 GB
# CPU Usage: 66.4%
# Learning Rate: 0.00025
# Loss: 1.36
# Num Updates: 50
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:34<00:00, 10.29s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 819
# Episode Reward Mean: 91
# Episode Score Mean: 1734
# Exploration Rate: 0.05
# Episodes: 3351
# Time per episode: 25960
# Frame per second: 78
# Time Elapsed: 26205.03 seconds
# Total Timesteps: 614266
# CPU Memory Usage: 6.64 GB
# CPU Usage: 67.5%
# Learning Rate: 0.00025
# Loss: 1.36
# Num Updates: 51
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:41<00:00, 10.44s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 814
# Episode Reward Mean: 88
# Episode Score Mean: 1500
# Exploration Rate: 0.05
# Episodes: 3401
# Time per episode: 26479
# Frame per second: 76
# Time Elapsed: 26726.98 seconds
# Total Timesteps: 624192
# CPU Memory Usage: 6.68 GB
# CPU Usage: 69.3%
# Learning Rate: 0.00025
# Loss: 1.41
# Num Updates: 52
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:51<00:00, 10.62s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 829
# Episode Reward Mean: 92
# Episode Score Mean: 1604
# Exploration Rate: 0.05
# Episodes: 3451
# Time per episode: 27011
# Frame per second: 76
# Time Elapsed: 27258.18 seconds
# Total Timesteps: 634287
# CPU Memory Usage: 6.71 GB
# CPU Usage: 70.3%
# Learning Rate: 0.00025
# Loss: 1.31
# Num Updates: 53
# ==========================================================================
# Training: 100%|██████████| 50/50 [09:18<00:00, 11.17s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 870
# Episode Reward Mean: 93
# Episode Score Mean: 1711
# Exploration Rate: 0.05
# Episodes: 3501
# Time per episode: 27548
# Frame per second: 76
# Time Elapsed: 27816.59 seconds
# Total Timesteps: 644899
# CPU Memory Usage: 6.75 GB
# CPU Usage: 72.8%
# Learning Rate: 0.00025
# Loss: 1.39
# Num Updates: 54
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:32<00:00, 10.24s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 817
# Episode Reward Mean: 89
# Episode Score Mean: 1597
# Exploration Rate: 0.05
# Episodes: 3551
# Time per episode: 28089
# Frame per second: 78
# Time Elapsed: 28328.76 seconds
# Total Timesteps: 654844
# CPU Memory Usage: 6.79 GB
# CPU Usage: 71.7%
# Learning Rate: 0.00025
# Loss: 1.47
# Num Updates: 55
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:53<00:00, 10.66s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 854
# Episode Reward Mean: 93
# Episode Score Mean: 1633
# Exploration Rate: 0.05
# Episodes: 3601
# Time per episode: 28611
# Frame per second: 78
# Time Elapsed: 28861.87 seconds
# Total Timesteps: 665261
# CPU Memory Usage: 6.83 GB
# CPU Usage: 71.6%
# Learning Rate: 0.00025
# Loss: 1.34
# Num Updates: 56
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:44<00:00, 10.49s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 845
# Episode Reward Mean: 90
# Episode Score Mean: 1698
# Exploration Rate: 0.05
# Episodes: 3651
# Time per episode: 29138
# Frame per second: 78
# Time Elapsed: 29386.17 seconds
# Total Timesteps: 675557
# CPU Memory Usage: 6.87 GB
# CPU Usage: 74.8%
# Learning Rate: 0.00025
# Loss: 1.29
# Num Updates: 57
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:22<00:00, 10.05s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 810
# Episode Reward Mean: 88
# Episode Score Mean: 1563
# Exploration Rate: 0.05
# Episodes: 3701
# Time per episode: 29648
# Frame per second: 78
# Time Elapsed: 29888.57 seconds
# Total Timesteps: 685407
# CPU Memory Usage: 6.91 GB
# CPU Usage: 74.4%
# Learning Rate: 0.00025
# Loss: 1.45
# Num Updates: 58
# ==========================================================================
# Training: 100%|██████████| 50/50 [08:19<00:00,  9.99s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 820
# Episode Reward Mean: 91
# Episode Score Mean: 1600
# Exploration Rate: 0.05
# Episodes: 3751
# Time per episode: 30143
# Frame per second: 80
# Time Elapsed: 30388.1 seconds
# Total Timesteps: 695348
# CPU Memory Usage: 6.95 GB
# CPU Usage: 74.5%
# Learning Rate: 0.00025
# Loss: 1.53
# Num Updates: 59
# ==========================================================================
# Training: 100%|██████████| 50/50 [09:05<00:00, 10.91s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 829
# Episode Reward Mean: 91
# Episode Score Mean: 1623
# Exploration Rate: 0.05
# Episodes: 3801
# Time per episode: 30655
# Frame per second: 74
# Time Elapsed: 30933.38 seconds
# Total Timesteps: 705436
# CPU Memory Usage: 6.99 GB
# CPU Usage: 79.7%
# Learning Rate: 0.00025
# Loss: 1.34
# Num Updates: 60
# ==========================================================================
# Training: 100%|██████████| 50/50 [10:02<00:00, 12.06s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 820
# Episode Reward Mean: 91
# Episode Score Mean: 1673
# Exploration Rate: 0.05
# Episodes: 3851
# Time per episode: 31240
# Frame per second: 66
# Time Elapsed: 31536.35 seconds
# Total Timesteps: 715423
# CPU Memory Usage: 6.84 GB
# CPU Usage: 79.7%
# Learning Rate: 0.00025
# Loss: 1.24
# Num Updates: 61
# ==========================================================================
# Training: 100%|██████████| 50/50 [09:40<00:00, 11.60s/episode]
# ============================ Training Summary ============================
# Episode Length Mean: 811
# Episode Reward Mean: 89
# Episode Score Mean: 1563
# Exploration Rate: 0.05
# Episodes: 3901
# Time per episode: 31836
# Frame per second: 68
# Time Elapsed: 32116.57 seconds
# Total Timesteps: 725304
# CPU Memory Usage: 6.88 GB
# CPU Usage: 81.2%
# Learning Rate: 0.00025
# Loss: 1.17
# Num Updates: 62
# ==========================================================================

# %%
#logs = model.evaluate(total_episodes=100)
