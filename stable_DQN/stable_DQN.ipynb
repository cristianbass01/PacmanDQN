# %%
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env.vec_frame_stack import VecFrameStack
from stable_baselines3.common.env_util import make_atari_env


env = make_atari_env("ALE/MsPacman-v5")
env = VecFrameStack(env, n_stack=4)

# Define the DQN model
model = DQN('CnnPolicy',
            env, 
            learning_rate = 0.00025,
            buffer_size = 100000,
            learning_starts =  10000,
            batch_size = 32,
            tau = 1.0,
            gamma = 0.99,
            target_update_interval = 10000,
            exploration_fraction = 0.4,
            exploration_initial_eps = 1.0,
            exploration_final_eps = 0.2,
            max_grad_norm = 10,
            verbose = 1
            )

# Train the model
model.learn(total_timesteps=1000000)

# Save the trained model
model.save("stable_dqn")

# Close the environment
env.close()
# Out:
# 2024-01-25 11:28:23.687195: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-25 11:28:23.687229: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-25 11:28:23.688444: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-25 11:28:23.695715: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-25 11:28:25.335582: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 453      |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 251      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 419      |
# |    ep_rew_mean      | 365      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 293      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | 348      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 308      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 404      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | 324      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 320      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 553      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | 328      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 329      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 744      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | 462      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 335      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 950      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 339      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 484      |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 340      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 339      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 336      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 486      |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 336      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 487      |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 337      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 482      |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 340      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 342      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 491      |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 343      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 492      |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 345      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 504      |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 346      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 522      |
# |    ep_rew_mean      | 511      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 348      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 514      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 349      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 349      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 548      |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 350      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 558      |
# |    ep_rew_mean      | 538      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 352      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 3975     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 569      |
# |    ep_rew_mean      | 548      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 352      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 532      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 352      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 4330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 560      |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 353      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 4480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 354      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 354      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 4849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 355      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 5050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 522      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 355      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 5172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 516      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 355      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 520      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 356      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 5593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 564      |
# |    ep_rew_mean      | 521      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 356      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 356      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 5911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 520      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 357      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 6127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 562      |
# |    ep_rew_mean      | 520      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 357      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 6282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 509      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 357      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 6422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 507      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 358      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 6571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 553      |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 358      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 6731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 553      |
# |    ep_rew_mean      | 515      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 358      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 6913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 553      |
# |    ep_rew_mean      | 521      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 358      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 7089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 554      |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 359      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 7287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 359      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 7529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 359      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 7708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 559      |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 360      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 7882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 557      |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 360      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 8041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 517      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 360      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 8185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 554      |
# |    ep_rew_mean      | 514      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 360      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 8356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 514      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 361      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 8559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 361      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 8745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 361      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 8928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 558      |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 361      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 9129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 555      |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 361      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 9266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 555      |
# |    ep_rew_mean      | 508      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 361      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 9484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 560      |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 361      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 9702     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 517      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 361      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 9935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 340      |
# |    time_elapsed     | 30       |
# |    total_timesteps  |

# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 94       |
# |    time_elapsed     | 532      |
# |    total_timesteps  | 50358    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10089    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 94       |
# |    time_elapsed     | 535      |
# |    total_timesteps  | 50536    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 543      |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 94       |
# |    time_elapsed     | 537      |
# |    total_timesteps  | 50685    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 94       |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 50810    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 94       |
# |    time_elapsed     | 541      |
# |    total_timesteps  | 50946    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 540      |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 94       |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 51072    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 542      |
# |    ep_rew_mean      | 467      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 93       |
# |    time_elapsed     | 545      |
# |    total_timesteps  | 51231    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 539      |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 93       |
# |    time_elapsed     | 547      |
# |    total_timesteps  | 51347    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | nan      |
# |    n_updates        | 10336    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 27
#      10 model = DQN('CnnPolicy',
#      11             env,
#      12             learning_rate = 0.00025,
#    (...)
#      23             verbose = 1
#      24             )
#      26 # Train the model
# ---> 27 model.learn(total_timesteps=1000000)
#      29 # Save the trained model
#      30 model.save("stable_dqn")
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py:33, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 33     observations, rewards, dones, infos = self.venv.step_wait()
#      34     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      35     return observations, rewards, dones, infos
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/core.py:461, in Wrapper.step(self, action)
#     457 def step(
#     458     self, action: WrapperActType
#     459 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     460     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 461     return self.env.step(action)
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/core.py:555, in RewardWrapper.step(self, action)
#     551 def step(
#     552     self, action: ActType
#     553 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     554     """Modifies the :attr:`env` :meth:`step` reward using :meth:`self.reward`."""
# --> 555     observation, reward, terminated, truncated, info = self.env.step(action)
#     556     return observation, self.reward(reward), terminated, truncated, info
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/core.py:522, in ObservationWrapper.step(self, action)
#     518 def step(
#     519     self, action: ActType
#     520 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     521     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 522     observation, reward, terminated, truncated, info = self.env.step(action)
#     523     return self.observation(observation), reward, terminated, truncated, info
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/atari_wrappers.py:112, in EpisodicLifeEnv.step(self, action)
#     111 def step(self, action: int) -> AtariStepReturn:
# --> 112     obs, reward, terminated, truncated, info = self.env.step(action)
#     113     self.was_real_done = terminated or truncated
#     114     # check current lives, make loss of life terminal,
#     115     # then update lives to handle bonus lives
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/atari_wrappers.py:178, in MaxAndSkipEnv.step(self, action)
#     176 terminated = truncated = False
#     177 for i in range(self._skip):
# --> 178     obs, reward, terminated, truncated, info = self.env.step(action)
#     179     done = terminated or truncated
#     180     if i == self._skip - 2:
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/core.py:461, in Wrapper.step(self, action)
#     457 def step(
#     458     self, action: WrapperActType
#     459 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     460     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 461     return self.env.step(action)
#
# File ~/miniconda3/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/miniconda3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/miniconda3/lib/python3.11/site-packages/shimmy/atari_env.py:294, in AtariEnv.step(self, action_ind)
#     292 reward = 0.0
#     293 for _ in range(frameskip):
# --> 294     reward += self.ale.act(action)
#     295 is_terminal = self.ale.game_over(with_truncation=False)
#     296 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
